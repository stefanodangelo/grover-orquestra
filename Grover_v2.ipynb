# %%
from build_circuit import build_circuit
from oracle_expansion import expand_oracle
from measure import run_and_measure
from qiskit.visualization import plot_histogram
from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister
import json
from modules.convert import load_circuit

# %%
element = "0001"
num_of_qubits = len(element)
circuit_path = 'circuit.json'
measurements_path = 'measurements.json'

# %%
build_circuit(num_of_qubits, circuit_path)

# %%
expand_oracle(circuit_path, element)

# %%
run_and_measure(circuit_path, backend='qasm_simulator', save_path=measurements_path)

# %%
with open(measurements_path, 'r') as f:
    results = json.load(f)
plot_histogram(results)

# %%
run_and_measure(circuit_path, save_path=measurements_path)
# Out:
# Job Status: job has successfully run

# %%
with open(measurements_path, 'r') as f:
    results = json.load(f)
plot_histogram(results)

# %%
from modules.convert import from_json
qc = from_json(circuit_path)
qc.draw('mpl', plot_barriers = False)
